# %%
# !git clone 'https://github.com/labwons/pylabwons-archive.git'
# %cd pylabwons-archive
# !pip install -r requirements.txt

# %% [markdown]
# # Config

# %%
# %cd ..
import os, sys; sys.path.append(os.path.join(os.getcwd(), 'pylabwons-archive/scripts'))
# Out:
# /

# %%
os.path.join(os.getcwd(), 'pylabwons-archive/scripts')
# Out:
# '/pylabwons-archive/scripts'

# %%
from src.core.build.baseline import Baseline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1239/3421929072.py in <cell line: 0>()
# ----> 1 from src.core.build.baseline import Baseline
#
# /content/pylabwons-archive/scripts/src/core/build/baseline.py in <module>
# ----> 1 from scripts.src.schema.dataframe import DataFrameHeir
#       2 from scripts.src.schema.key import BASELINE
#       3 from scripts.src.core.fetch.aftermarket import AfterMarket
#       4 from scripts.src.core.fetch.numbers import Numbers
#       5 from scripts.src.core.fetch.wics import Wics
#
# ModuleNotFoundError: No module named 'scripts'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# ...
