# %%
# !pip install pylabwons

# %%
import pylabwons as lw
import os
IS_COLAB = any([key.startswith('COLAB') for key in os.environ])
if IS_COLAB:
    from google.colab import files
else:
    from scripts.env import PATH

# %% [markdown]
# # WISE INDUSTRY CLASSIFICATION SYSTEM

# %%
wics = lw.WiseICS()
wics.fetch()
print(wics.logger)
if IS_COLAB:
    wics.to_parquet('wics.parquet', engine='pyarrow')
    files.download('wics.parquet')
else:
    wics.to_parquet(PATH.PARQ.WICS, engine='pyarrow')
# Out:
# 2026-02-08 21:55:54 FETCH WICS ON 20260206
# 2026-02-08 21:55:55 >>> [1/26]에너지@WI100 ... OK
# 2026-02-08 21:55:56 >>> [2/26]화학@WI110 ... OK
# 2026-02-08 21:55:57 >>> [3/26]비철금속@WI200 ... OK
# 2026-02-08 21:55:58 >>> [4/26]철강@WI210 ... OK
# 2026-02-08 21:55:59 >>> [5/26]건설@WI220 ... OK
# 2026-02-08 21:56:00 >>> [6/26]기계@WI230 ... OK
# 2026-02-08 21:56:01 >>> [7/26]조선@WI240 ... OK
# 2026-02-08 21:56:02 >>> [8/26]상사,자본재@WI250 ... OK
# 2026-02-08 21:56:02 >>> [9/26]운송@WI260 ... OK
# 2026-02-08 21:56:03 >>> [10/26]자동차@WI300 ... OK
# 2026-02-08 21:56:04 >>> [11/26]화장품,의류@WI310 ... OK
# 2026-02-08 21:56:05 >>> [12/26]호텔,레저@WI320 ... OK
# 2026-02-08 21:56:06 >>> [13/26]미디어,교육@WI330 ... OK
# 2026-02-08 21:56:08 >>> [14/26]소매(유통)@WI340 ... OK
# 2026-02-08 21:56:09 >>> [15/26]필수소비재@WI400 ... OK
# 2026-02-08 21:56:10 >>> [16/26]건강관리@WI410 ... OK
# 2026-02-08 21:56:13 >>> [17/26]은행@WI500 ... OK
# 2026-02-08 21:56:15 >>> [18/26]증권@WI510 ... OK
# 2026-02-08 21:56:17 >>> [19/26]보험@WI520 ... OK
# 2026-02-08 21:56:18 >>> [20/26]소프트웨어@WI600 ... OK
# 2026-02-08 21:56:19 >>> [21/26]IT하드웨어@WI610 ... OK
# 2026-02-08 21:56:20 >>> [22/26]반도체@WI620 ... OK
# 2026-02-08 21:56:21 >>> [23/26]IT가전@WI630 ... OK
# 2026-02-08 21:56:22 >>> [24/26]디스플레이@WI640 ... OK
# 2026-02-08 21:56:23 >>> [25/26]통신서비스@WI700 ... OK
# 2026-02-08 21:56:24 >>> [26/26]유틸리티@WI800 ... OK
# 2026-02-08 21:56:24 .............................. 2466 STOCKS / RUNTIME: 30.74s

# %% [markdown]
# # AFTER MARKET

# %%
market = lw.AfterMarket()
market.fetch()
print(market.logger)
if IS_COLAB:
    market.to_parquet('aftermarket.parquet', engine='pyarrow')
    files.download('aftermarket.parquet')
else:
    market.to_parquet(PATH.PARQ.AFTERMARKET, engine='pyarrow')
